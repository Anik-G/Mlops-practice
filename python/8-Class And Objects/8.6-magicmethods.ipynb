# %% [markdown]
# #### Magic Methods
# Magic methods in Python, also known as dunder methods (double underscore methods), are special methods that start and end with double underscores. These methods enable you to define the behavior of objects for built-in operations, such as arithmetic operations, comparisons, and more.

# %% [markdown]
# ##### Magic Methods
# Magic methods are predefined methods in Python that you can override to change the behavior of your objects. Some common magic methods include:

# %%
'''
__init__: Initializes a new instance of a class.
__str__: Returns a string representation of an object.
__repr__: Returns an official string representation of an object.
__len__: Returns the length of an object.
__getitem__: Gets an item from a container.
__setitem__: Sets an item in a container.
__class__': Returns the class of the object.
__delattr__': Deletes an attribute of the object.
__dict__': Dictionary containing the object's attributes.
__dir__': Returns a list of valid attributes for the object.
__doc__': Documentation string for the object.
__eq__': Compares two objects for equality.
__format__': Formats the object.
__ge__': Greater than or equal to comparison.
__getattribute__': Gets an attribute of the object.
__getstate__': Gets the state of the object for pickling.
__gt__': Greater than comparison.
__hash__': Returns the hash value of the object.
__init_subclass__': Called when a subclass is created.
__le__': Less than or equal to comparison.
__lt__': Less than comparison.
__module__': Module where the class is defined.
__ne__': Not equal comparison.
__new__': Creates a new instance of the class.
__reduce__': Reduces the object for pickling.
__reduce_ex__': Reduces the object for pickling with protocol.
__setattr__': Sets an attribute of the object.
__sizeof__': Returns the size of the object in memory.
__subclasshook__': Hook for subclass checking.
__weakref__': Weak reference to the object.
'''
# Out:
# "\n__init__: Initializes a new instance of a class.\n__str__: Returns a string representation of an object.\n__repr__: Returns an official string representation of an object.\n__len__: Returns the length of an object.\n__getitem__: Gets an item from a container.\n__setitem__: Sets an item in a container.\n__class__': Returns the class of the object.\n__delattr__': Deletes an attribute of the object.\n__dict__': Dictionary containing the object's attributes.\n__dir__': Returns a list of valid attributes for the object.\n__doc__': Documentation string for the object.\n__eq__': Compares two objects for equality.\n__format__': Formats the object.\n__ge__': Greater than or equal to comparison.\n__getattribute__': Gets an attribute of the object.\n__getstate__': Gets the state of the object for pickling.\n__gt__': Greater than comparison.\n__hash__': Returns the hash value of the object.\n__init_subclass__': Called when a subclass is created.\n__le__': Less than or equal to comparison.\n__
# ...

# %%
class Person:
    pass

person=Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)

# %%
## Basics MEthods
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
person=Person("Anik",32)
print(person)

# %%
## Basics MEthods
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def __str__(self):
        return f"{self.name},{self.age} years old"
    
    def __repr__(self):
        return f"Person(name={self.name},age={self.age})"
    
person=Person("Anik",32)
print(person)
print(repr(person))
# Out:
# Anik,32 years old
# Person(name=Anik,age=32)
